# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("salesforcourse-4fe2kehu.csv")
df
# Out:
#        index       Date    Year     Month  Customer Age Customer Gender  \
# 0          0  2/19/2016  2016.0  February          29.0               F
# 1          1  2/20/2016  2016.0  February          29.0               F
# 2          2  2/27/2016  2016.0  February          29.0               F
# 3          3  3/12/2016  2016.0     March          29.0               F
# 4          4  3/12/2016  2016.0     March          29.0               F
# ...      ...        ...     ...       ...           ...             ...
# 34862  34862   2/7/2016  2016.0  February          38.0               M
# 34863  34863  3/13/2015  2015.0     March          38.0               M
# 34864  34864   4/5/2015  2015.0     April          38.0               M
# 34865  34865  8/30/2015  2015.0    August          38.0               M
# 34866  34866        NaN     NaN       NaN           NaN             NaN
#
#              Country           State Product Category     Sub Category  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34867 entries, 0 to 34866
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   index             34867 non-null  int64
#  1   Date              34866 non-null  object
#  2   Year              34866 non-null  float64
#  3   Month             34866 non-null  object
#  4   Customer Age      34866 non-null  float64
#  5   Customer Gender   34866 non-null  object
#  6   Country           34866 non-null  object
#  7   State             34866 non-null  object
#  8   Product Category  34866 non-null  object
#  9   Sub Category      34866 non-null  object
#  10  Quantity          34866 non-null  float64
#  11  Unit Cost         34866 non-null  float64
#  12  Unit Price        34866 non-null  float64
#  13  Cost              34866 non-null  float64
#  14  Revenue           34867 non-null  float64
#  15  Column1           2574 non-null   float64
# ...

# %% [markdown]
# ### Year Analysis

# %%
year_count=df['Year'].value_counts()
year_percent=df['Year'].value_counts(normalize=True)*100
freq_table1=pd.DataFrame({'Frequency':year_count,'Percentage %':year_percent})
freq_table1
# Out:
#         Frequency  Percentage %
# Year
# 2016.0      19847     56.923651
# 2015.0      15019     43.076349

# %%
plt.pie(year_count,labels=['2016','2015'],colors=['cyan','purple'],shadow=True,autopct='%1.1f%%')
plt.legend()
plt.show()

# %% [markdown]
# - 2016 is the most year of transaction occured

# %% [markdown]
# ### Month Analysis

# %%
month_count=df['Month'].value_counts()
month_percent=df['Month'].value_counts(normalize=True)*100
freq_table2=pd.DataFrame({'Frequency':month_count,'Percentage %':month_percent})
freq_table2
# Out:
#            Frequency  Percentage %
# Month
# June            3680     10.554695
# May             3676     10.543223
# December        3414      9.791774
# April           3283      9.416050
# March           3155      9.048930
# January         2907      8.337636
# February        2887      8.280273
# October         2554      7.325188
# November        2488      7.135892
# August          2304      6.608157
# September       2303      6.605289
# July            2215      6.352894

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='Month',data=df)
plt.show()

# %% [markdown]
# - June & May are the most months of transaction occured

# %%
df.groupby(['Year'])['Month'].value_counts()
# Out:
# Year    Month
# 2015.0  December     3414
#         October      2554
#         November     2488
#         August       2304
#         September    2303
#         July          928
#         June          206
#         May           204
#         April         177
#         February      154
#         March         149
#         January       138
# 2016.0  June         3474
#         May          3472
#         April        3106
#         March        3006
#         January      2769
#         February     2733
#         July         1287
# Name: count, dtype: int64

# %% [markdown]
# ### Customer Analysis

# %% [markdown]
# #### Age

# %%
df['Customer Age'].describe()
# Out:
# count    34866.000000
# mean        36.382895
# std         11.112902
# min         17.000000
# 25%         28.000000
# 50%         35.000000
# 75%         44.000000
# max         87.000000
# Name: Customer Age, dtype: float64

# %%
plt.hist(df['Customer Age'],bins=15,edgecolor='purple',color='cyan',linewidth=1)
plt.title('Age Frequency')
plt.xlabel('Age')
plt.ylabel('Freq')
plt.show()

# %%
sns.boxplot(df['Customer Age'],orient='h',fill=True,color='purple')
plt.show()

# %% [markdown]
# - Most of customers age are from 30 to 45 years

# %% [markdown]
# #### Gender

# %%
gender_count=df['Customer Gender'].value_counts()
gender_percent=df['Customer Gender'].value_counts(normalize=True)*100
freq_table3=pd.DataFrame({'Frequency':gender_count,'Percentage %':gender_percent})
freq_table3
# Out:
#                  Frequency  Percentage %
# Customer Gender
# M                    17805     51.066942
# F                    17061     48.933058

# %%
plt.pie(gender_count,labels=['Males','Females'],colors=['blue','pink'],shadow=True,autopct='%1.1f%%')
plt.legend()
plt.show()

# %% [markdown]
# - The number of male customers is very close to the number of female customers.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34867 entries, 0 to 34866
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   index                    34867 non-null  int64
#  1   Date                     34866 non-null  object
#  2   Year                     34866 non-null  float64
#  3   Month                    34866 non-null  object
#  4   Customer Age             34866 non-null  float64
#  5   Customer Gender          34866 non-null  object
#  6   Country                  34866 non-null  object
#  7   State                    34866 non-null  object
#  8   Product Category         34866 non-null  object
#  9   Sub Category             34866 non-null  object
#  10  Quantity                 34866 non-null  float64
#  11  Unit Cost                34866 non-null  float64
#  12  Unit Price               34866 non-null  float64
#  13  Cost                     34866 non-null  float64
# ...

# %%
country_count=df['Country'].value_counts()
country_percent=df['Country'].value_counts(normalize=True)*100
freq_table4=pd.DataFrame({'Frequency':country_count,'Percentage %':country_percent})
freq_table4
# Out:
#                 Frequency  Percentage %
# Country
# United States       18076     51.844204
# United Kingdom       6421     18.416222
# Germany              5201     14.917111
# France               5168     14.822463

# %%
sns.countplot(x='Country',palette='viridis',data=df)
plt.title('', fontsize=16)
plt.xlabel('Country', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.xticks(rotation=45, fontsize=10)
plt.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18828\685608170.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Country',palette='viridis',data=df)

# %% [markdown]
# - United States is the country with the most transaction occured.

# %%
state_count=df['State'].value_counts().head(10)
state_count
# Out:
# State
# California             10332
# England                 6421
# Washington              5204
# Oregon                  2446
# Saarland                1287
# Nordrhein-Westfalen     1171
# Hessen                  1112
# Seine (Paris)           1092
# Hamburg                  869
# Seine Saint Denis        796
# Name: count, dtype: int64

# %%
palette = sns.color_palette('cividis', len(state_count))
plt.figure(figsize=(7, 3))
plt.bar(state_count.index, state_count, color=palette)
plt.title('Top 10 States')
plt.xlabel('States')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - California is the State with the most transactions occured

# %%
cat_count=df['Product Category'].value_counts()
cat_percent=df['Product Category'].value_counts(normalize=True)*100
freq_table5=pd.DataFrame({'Frequency':cat_count,'Percentage %':cat_percent})
freq_table5
# Out:
#                   Frequency  Percentage %
# Product Category
# Accessories           22534     64.630299
# Bikes                  7093     20.343601
# Clothing               5239     15.026100

# %%
palette = sns.color_palette('twilight_shifted')
plt.pie(cat_count,labels=cat_count.index,colors=palette,shadow=True,autopct='%1.1f%%')
plt.legend()
plt.show()

# %% [markdown]
# - Accessories is the most sold product.

# %% [markdown]
# ### Correlation

# %%
plt.subplot(2, 2, 1)
plt.scatter(df['Unit Price'], df['Revenue'])
plt.title('Unit Price vs. Revenue')
plt.xlabel('Unit Price')
plt.ylabel('Revenue')


plt.subplot(2, 2, 2)
plt.scatter(df['Unit Cost'], df['Cost'])
plt.title('Unit Cost vs. Cost')
plt.xlabel('Unit Cost')
plt.ylabel('Cost')


plt.subplot(2, 2, 3)
plt.scatter(df['Unit Price'], df['Cost'])
plt.title('Unit Price vs. Cost')
plt.xlabel('Unit Price')
plt.ylabel('Cost')


plt.subplot(2, 2, 4)
plt.scatter(df['Unit Cost'], df['Revenue'])
plt.title('Unit Cost vs. Revenue')
plt.xlabel('Unit Cost')
plt.ylabel('Revenue')

plt.tight_layout()
plt.show()

# %% [markdown]
# - Unit price vs Revenu higher unit prices generally correspond to higher revenues.
# - Unit cost vs Cost strong positive linear relationship.
# - Unit price vs Cost spread of data points, with a positive relationship.
# - Unit price vs revenue positive relationship, but the data points are widely scattered.

# %%
df2=df.iloc[:, -6:-2]
cm = df2.corr(numeric_only=True)
sns.heatmap(cm,annot=True,cmap='coolwarm')
# Out:
# <Axes: >
